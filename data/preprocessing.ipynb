# %% [markdown]
# CHRONIC KIDNEY DISEASE DETECTION PROJECT

# %%
# %pip install seaborn

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# Out:
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\sagar shresti\Desktop\ckd\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\sagar shresti\Desktop\ckd\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\sagar shresti\Desktop\ckd\.venv\Lib\site-packages)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
dataset = pd.read_csv("ckdd.csv", on_bad_lines='skip')
dataset.head(3)
# Out:
#   age  bg     sg al su     rbc      pc         pcc          ba  bgr  ... wbcc  \
# 0  48  80  1.020  1  0       ?  normal  notpresent  notpresent  121  ...   44
# 1   7  50  1.020  4  0       ?  normal  notpresent  notpresent    ?  ...   38
# 2  62  80  1.010  2  3  normal  normal  notpresent  notpresent  423  ...   31
#
#    rbcc  htn   dm  cad appet    pe ane class prediction
# 0  7800  5.2  yes  yes    no  good  no    no        ckd
# 1  6000    ?   no   no    no  good  no    no        ckd
# 2  7500    ?   no  yes    no  poor  no   yes        ckd
#
# [3 rows x 25 columns]

# %%
dataset.shape
# Out:
# (397, 25)

# %%
dataset.shape[0]
# Out:
# 397

# %%
dataset.isnull().sum()
# Out:
# age           0
# bg            0
# sg            0
# al            0
# su            0
# rbc           0
# pc            0
# pcc           0
# ba            0
# bgr           0
# sc            0
# sod           0
# pot           0
# hemo          0
# pcv           0
# wbcc          0
# rbcc          0
# htn           0
# dm            0
# cad           0
# appet         0
# pe            0
# ane           0
# class         0
# prediction    0
# dtype: int64

# %%
dataset.notnull().sum()
# Out:
# age           397
# bg            397
# sg            397
# al            397
# su            397
# rbc           397
# pc            397
# pcc           397
# ba            397
# bgr           397
# sc            397
# sod           397
# pot           397
# hemo          397
# pcv           397
# wbcc          397
# rbcc          397
# htn           397
# dm            397
# cad           397
# appet         397
# pe            397
# ane           397
# class         397
# prediction    397
# dtype: int64

# %%
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1])) * 100
# Out:
# 0.0

# %%
dataset.isnull().sum()/dataset.shape[0] * 100
# Out:
# age           0.0
# bg            0.0
# sg            0.0
# al            0.0
# su            0.0
# rbc           0.0
# pc            0.0
# pcc           0.0
# ba            0.0
# bgr           0.0
# sc            0.0
# sod           0.0
# pot           0.0
# hemo          0.0
# pcv           0.0
# wbcc          0.0
# rbcc          0.0
# htn           0.0
# dm            0.0
# cad           0.0
# appet         0.0
# pe            0.0
# ane           0.0
# class         0.0
# prediction    0.0
# dtype: float64

# %% [markdown]
# NO NULL VALUES FOUND

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.head(25)
# Out:
#    age   bg     sg al su       rbc        pc         pcc          ba  bgr  \
# 0   48   80  1.020  1  0         ?    normal  notpresent  notpresent  121
# 1    7   50  1.020  4  0         ?    normal  notpresent  notpresent    ?
# 2   62   80  1.010  2  3    normal    normal  notpresent  notpresent  423
# 3   48   70  1.005  4  0    normal  abnormal     present  notpresent  117
# 4   51   80  1.010  2  0    normal    normal  notpresent  notpresent  106
# 5   60   90  1.015  3  0         ?         ?  notpresent  notpresent   74
# 6   68   70  1.010  0  0         ?    normal  notpresent  notpresent  100
# 7   24    ?  1.015  2  4    normal  abnormal  notpresent  notpresent  410
# 8   52  100  1.015  3  0    normal  abnormal     present  notpresent  138
# 9   53   90  1.020  2  0  abnormal  abnormal     present  notpresent   70
# 10  50   60  1.010  2  4         ?  abnormal     present  notpresent  490
# 11  63   70  1.010  3  0  abnormal  abnormal     present  notpresent  380
# ...

# %% [markdown]
# replace the ? by mode value of column

# %%
dataset["pc"].replace("?", pd.NA, inplace=True)
dataset["pc"].fillna(dataset["pc"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\4291129737.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["pc"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\4291129737.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dataset["rbc"].replace("?", pd.NA, inplace=True)
dataset["rbc"].fillna(dataset["rbc"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\2506719877.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["rbc"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\2506719877.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dataset["rbcc"].replace("?", pd.NA, inplace=True)
dataset["rbcc"].fillna(dataset["rbcc"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\2103294823.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["rbcc"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\2103294823.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dataset["htn"].replace("?", pd.NA, inplace=True)
dataset["htn"].fillna(dataset["htn"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\4221886325.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["htn"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\4221886325.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dataset["al"].replace("?", pd.NA, inplace=True)
dataset["al"].fillna(dataset["al"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\4128063076.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["al"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\4128063076.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dataset["su"].replace("?", pd.NA, inplace=True)
dataset["su"].fillna(dataset["su"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\201760471.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["su"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\201760471.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dataset["bgr"].replace("?", pd.NA, inplace=True)
dataset["bgr"].fillna(dataset["bgr"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3904714816.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["bgr"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3904714816.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dataset["wbcc"].replace("?", pd.NA, inplace=True)
dataset["wbcc"].fillna(dataset["wbcc"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\4055727874.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["wbcc"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\4055727874.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 25 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         397 non-null    object
#  1   bg          397 non-null    object
#  2   sg          397 non-null    object
#  3   al          397 non-null    object
#  4   su          397 non-null    object
#  5   rbc         397 non-null    object
#  6   pc          397 non-null    object
#  7   pcc         397 non-null    object
#  8   ba          397 non-null    object
#  9   bgr         397 non-null    object
#  10  sc          397 non-null    object
#  11  sod         397 non-null    object
#  12  pot         397 non-null    object
#  13  hemo        397 non-null    object
#  14  pcv         397 non-null    object
#  15  wbcc        397 non-null    object
#  16  rbcc        397 non-null    object
#  17  htn         397 non-null    object
#  18  dm          397 non-null    object
# ...

# %%
print(dataset.columns)
print(dataset.dtypes)
# Out:
# Index(['age', 'bg', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'sc',
#        'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'class', 'prediction'],
#       dtype='object')
# age           object
# bg            object
# sg            object
# al            object
# su            object
# rbc           object
# pc            object
# pcc           object
# ba            object
# bgr           object
# sc            object
# sod           object
# pot           object
# hemo          object
# pcv           object
# wbcc          object
# rbcc          object
# htn           object
# dm            object
# cad           object
# appet         object
# pe            object
# ane           object
# class         object
# prediction    object
# dtype: object

# %%
dataset.head(25)
# Out:
#    age   bg     sg al su       rbc        pc         pcc          ba  bgr  \
# 0   48   80  1.020  1  0    normal    normal  notpresent  notpresent  121
# 1    7   50  1.020  4  0    normal    normal  notpresent  notpresent   99
# 2   62   80  1.010  2  3    normal    normal  notpresent  notpresent  423
# 3   48   70  1.005  4  0    normal  abnormal     present  notpresent  117
# 4   51   80  1.010  2  0    normal    normal  notpresent  notpresent  106
# 5   60   90  1.015  3  0    normal    normal  notpresent  notpresent   74
# 6   68   70  1.010  0  0    normal    normal  notpresent  notpresent  100
# 7   24    ?  1.015  2  4    normal  abnormal  notpresent  notpresent  410
# 8   52  100  1.015  3  0    normal  abnormal     present  notpresent  138
# 9   53   90  1.020  2  0  abnormal  abnormal     present  notpresent   70
# 10  50   60  1.010  2  4    normal  abnormal     present  notpresent  490
# 11  63   70  1.010  3  0  abnormal  abnormal     present  notpresent  380
# ...

# %%
dataset["bg"].replace("?", pd.NA, inplace=True)
dataset["bg"].fillna(dataset["bg"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\443715465.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["bg"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\443715465.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dataset["sg"].replace("?", pd.NA, inplace=True)
dataset["sg"].fillna(dataset["sg"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3336743745.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["sg"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3336743745.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dataset["pot"].replace("?", pd.NA, inplace=True)
dataset["pot"].fillna(dataset["pot"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\2172870675.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["pot"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\2172870675.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dataset["hemo"].replace("?", pd.NA, inplace=True)
dataset["hemo"].fillna(dataset["hemo"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\4066267146.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["hemo"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\4066267146.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dataset["wbcc"].replace("?", pd.NA, inplace=True)
dataset["wbcc"].fillna(dataset["wbcc"].mode()[0],inplace=True)

# %%
dataset["pcv"].replace("?", pd.NA, inplace=True)
dataset["pcv"].fillna(dataset["pcv"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\905779677.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["pcv"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\905779677.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# cleaned dataset with 25 columns

# %%
pd.set_option('display.max_columns', None)
dataset.head(50)
# Out:
#    age   bg     sg al su       rbc        pc         pcc          ba  bgr  \
# 0   48   80  1.020  1  0    normal    normal  notpresent  notpresent  121
# 1    7   50  1.020  4  0    normal    normal  notpresent  notpresent   99
# 2   62   80  1.010  2  3    normal    normal  notpresent  notpresent  423
# 3   48   70  1.005  4  0    normal  abnormal     present  notpresent  117
# 4   51   80  1.010  2  0    normal    normal  notpresent  notpresent  106
# 5   60   90  1.015  3  0    normal    normal  notpresent  notpresent   74
# 6   68   70  1.010  0  0    normal    normal  notpresent  notpresent  100
# 7   24   80  1.015  2  4    normal  abnormal  notpresent  notpresent  410
# 8   52  100  1.015  3  0    normal  abnormal     present  notpresent  138
# 9   53   90  1.020  2  0  abnormal  abnormal     present  notpresent   70
# 10  50   60  1.010  2  4    normal  abnormal     present  notpresent  490
# 11  63   70  1.010  3  0  abnormal  abnormal     present  notpresent  380
# ...

# %%
dataset["sod"].replace("?", pd.NA, inplace=True)
dataset["sod"].fillna(dataset["sod"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3971702397.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["sod"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3971702397.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dataset["prediction"].replace("?", pd.NA, inplace=True)
dataset["prediction"].fillna(dataset["prediction"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\1777868222.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["prediction"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\1777868222.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dataset["prediction"].replace("ckd\t", pd.NA, inplace=True)
dataset["prediction"].fillna(dataset["prediction"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\151680886.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["prediction"].replace("ckd\t", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\151680886.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dataset["pcv"].replace("?", pd.NA, inplace=True)
dataset["pcv"].fillna(dataset["pcv"].mode()[0],inplace=True)

# %%
dataset["age"].replace("?", pd.NA, inplace=True)
dataset["age"].fillna(dataset["age"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\2186252292.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["age"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\2186252292.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dataset["appet"].replace("\tno", pd.NA, inplace=True)
dataset["appet"].fillna(dataset["appet"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\668693629.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["appet"].replace("\tno", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\668693629.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dataset["appet"].replace("?", pd.NA, inplace=True)
dataset["appet"].fillna(dataset["appet"].mode()[0],inplace=True)

# %%
dataset["sc"].replace("?", pd.NA, inplace=True)
dataset["sc"].fillna(dataset["sc"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\63103497.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["sc"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\63103497.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dataset.describe()
# Out:
#         age   bg     sg   al   su     rbc      pc         pcc          ba  \
# count   397  397    397  397  397     397     397         397         397
# unique   75   10      5    6    6       2       2           3           3
# top      60   80  1.020    0    0  normal  normal  notpresent  notpresent
# freq     28  128    152  243  338     350     322         352         371
#
#         bgr   sc  sod  pot hemo   pcv wbcc  rbcc  htn   dm  cad appet    pe  \
# count   397  397  397  397  397   397  397   397  397  397  397   397   397
# unique  145  118   86   34   42   118   44    92   49    3    6     2     3
# top      99   46  1.2  135  3.5  15.0   41  9800  5.2   no   no    no  good
# freq     53   34   57  125  115    64   90   115  147  249  257   363   314
#
#         ane class prediction
# count   397   397        397
# unique    3     3          2
# top      no    no        ckd
# freq    321   336        248

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 25 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         397 non-null    object
#  1   bg          397 non-null    object
#  2   sg          397 non-null    object
#  3   al          397 non-null    object
#  4   su          397 non-null    object
#  5   rbc         397 non-null    object
#  6   pc          397 non-null    object
#  7   pcc         397 non-null    object
#  8   ba          397 non-null    object
#  9   bgr         397 non-null    object
#  10  sc          397 non-null    object
#  11  sod         397 non-null    object
#  12  pot         397 non-null    object
#  13  hemo        397 non-null    object
#  14  pcv         397 non-null    object
#  15  wbcc        397 non-null    object
#  16  rbcc        397 non-null    object
#  17  htn         397 non-null    object
#  18  dm          397 non-null    object
# ...

# %%
# Install required packages
# %pip install ctgan scikit-learn imbalanced-learn joblib

from ctgan import CTGAN
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from imblearn.over_sampling import SMOTE

# Prepare your cleaned dataset
data_for_ctgan = dataset.dropna().copy()

# Identify categorical columns (object or category dtype)
categorical_cols = data_for_ctgan.select_dtypes(include=['object', 'category']).columns.tolist()

# Train CTGAN
ctgan = CTGAN()
ctgan.fit(data_for_ctgan, discrete_columns=categorical_cols)
synthetic_data = ctgan.sample(500)

# Combine real and synthetic data
full_data = pd.concat([data_for_ctgan, synthetic_data], ignore_index=True)

# Encode categorical columns for ML
for col in categorical_cols:
    full_data[col] = full_data[col].astype('category').cat.codes

# Balance the dataset using SMOTE
X = full_data.drop('prediction', axis=1)
y = full_data['prediction']

smote = SMOTE()
X_bal, y_bal = smote.fit_resample(X, y)

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X_bal, y_bal, test_size=0.2, random_state=42)

# Train RandomForest
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train, y_train)

# Evaluate
y_pred = clf.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\sagar shresti\Desktop\ckd\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\sagar shresti\Desktop\ckd\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\sagar shresti\Desktop\ckd\.venv\Lib\site-packages)
# ...
# Note: you may need to restart the kernel to use updated packages.
# Accuracy: 0.8577586206896551
#               precision    recall  f1-score   support
#
#            0       0.81      0.95      0.87       121
#            1       0.93      0.76      0.84       111
#
#     accuracy                           0.86       232
#    macro avg       0.87      0.85      0.86       232
# weighted avg       0.87      0.86      0.86       232

# %%
# Save synthetic data to CSV
synthetic_data.to_csv('synthetic_ckd.csv', index=False)

# %%
synthetic_data.shape
# Out:
# (500, 25)

# %%
synthetic_data.isnull().sum()
# Out:
# age           0
# bg            0
# sg            0
# al            0
# su            0
# rbc           0
# pc            0
# pcc           0
# ba            0
# bgr           0
# sc            0
# sod           0
# pot           0
# hemo          0
# pcv           0
# wbcc          0
# rbcc          0
# htn           0
# dm            0
# cad           0
# appet         0
# pe            0
# ane           0
# class         0
# prediction    0
# dtype: int64

# %%
sns.heatmap(synthetic_data.isnull())
plt.show()

# %%
synthetic_data.head(20)
# Out:
#    age   bg     sg al su       rbc        pc         pcc          ba  bgr  \
# 0   37   60  1.010  1  0    normal  abnormal  notpresent  notpresent   99
# 1   23   60  1.020  0  0    normal    normal  notpresent  notpresent  251
# 2   59   70  1.020  1  0    normal  abnormal  notpresent  notpresent  140
# 3   72   60  1.020  4  0    normal  abnormal     present  notpresent  119
# 4   48   70  1.010  0  0    normal  abnormal  notpresent  notpresent   86
# 5   50   60  1.015  0  0    normal  abnormal  notpresent  notpresent   75
# 6   60  100  1.020  0  0  abnormal    normal  notpresent  notpresent  308
# 7   65   70  1.010  1  0    normal    normal  notpresent  notpresent   74
# 8   74  100  1.010  0  0    normal    normal  notpresent  notpresent  114
# 9   80   60  1.020  1  0    normal    normal  notpresent  notpresent  295
# 10  43   70  1.015  0  2    normal    normal  notpresent           ?  113
# 11  34  110  1.020  3  0    normal    normal  notpresent  notpresent   93
# ...

# %%
import pandas as pd

# Load both datasets, skipping bad lines in the real data
real_data = pd.read_csv('ckdd.csv', on_bad_lines='skip')
synthetic_data = pd.read_csv('synthetic_ckd.csv')

# Concatenate them
combined_data = pd.concat([real_data, synthetic_data], ignore_index=True)

# Save the combined dataset
combined_data.to_csv('combined_ckd.csv', index=False)

# %%
combined_data.shape
# Out:
# (897, 25)

# %%
combined_data.head(3)
# Out:
#   age  bg     sg al su     rbc      pc         pcc          ba  bgr  sc  sod  \
# 0  48  80  1.020  1  0       ?  normal  notpresent  notpresent  121  36  1.2
# 1   7  50  1.020  4  0       ?  normal  notpresent  notpresent    ?  18  0.8
# 2  62  80  1.010  2  3  normal  normal  notpresent  notpresent  423  53  1.8
#
#   pot hemo   pcv wbcc  rbcc  htn   dm  cad appet    pe ane class prediction
# 0   ?    ?  15.4   44  7800  5.2  yes  yes    no  good  no    no        ckd
# 1   ?    ?  11.3   38  6000    ?   no   no    no  good  no    no        ckd
# 2   ?    ?   9.6   31  7500    ?   no  yes    no  poor  no   yes        ckd

# %%
combined_data["sc"].replace("?", pd.NA, inplace=True)
combined_data["sc"].fillna(combined_data["sc"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\2078286435.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["sc"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\2078286435.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["sod"].replace("?", pd.NA, inplace=True)
combined_data["sod"].fillna(combined_data["sod"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\496785765.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["sod"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\496785765.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["class"].replace("?", pd.NA, inplace=True)
combined_data["class"].fillna(combined_data["class"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3358510518.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["class"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3358510518.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["ane"].replace("?", pd.NA, inplace=True)
combined_data["ane"].fillna(combined_data["ane"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\1522175204.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["ane"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\1522175204.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["pe"].replace("?", pd.NA, inplace=True)
combined_data["pe"].fillna(combined_data["pe"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\1902318068.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["pe"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\1902318068.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["appet"].replace("?", pd.NA, inplace=True)
combined_data["appet"].fillna(combined_data["appet"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3755891039.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["appet"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3755891039.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["cad"].replace("?", pd.NA, inplace=True)
combined_data["cad"].fillna(combined_data["cad"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\374643761.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["cad"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\374643761.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["dm"].replace("?", pd.NA, inplace=True)
combined_data["dm"].fillna(combined_data["dm"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3392545991.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["dm"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3392545991.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["htn"].replace("?", pd.NA, inplace=True)
combined_data["htn"].fillna(combined_data["htn"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\4122370236.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["htn"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\4122370236.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["rbcc"].replace("?", pd.NA, inplace=True)
combined_data["rbcc"].fillna(combined_data["rbcc"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\1102262119.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["rbcc"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\1102262119.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["wbcc"].replace("?", pd.NA, inplace=True)
combined_data["wbcc"].fillna(combined_data["wbcc"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3938375212.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["wbcc"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3938375212.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["pcv"].replace("?", pd.NA, inplace=True)
combined_data["pcv"].fillna(combined_data["pcv"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\1545139396.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["pcv"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\1545139396.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["hemo"].replace("?", pd.NA, inplace=True)
combined_data["hemo"].fillna(combined_data["hemo"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\368804391.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["hemo"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\368804391.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["pot"].replace("?", pd.NA, inplace=True)
combined_data["pot"].fillna(combined_data["pot"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3698793939.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["pot"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3698793939.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["bgr"].replace("?", pd.NA, inplace=True)
combined_data["bgr"].fillna(combined_data["bgr"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\1094117766.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["bgr"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\1094117766.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["ba"].replace("?", pd.NA, inplace=True)
combined_data["ba"].fillna(combined_data["ba"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\2349259043.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["ba"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\2349259043.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["age"].replace("?", pd.NA, inplace=True)
combined_data["age"].fillna(combined_data["age"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\567320676.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["age"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\567320676.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["bg"].replace("?", pd.NA, inplace=True)
combined_data["bg"].fillna(combined_data["bg"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3376820041.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["bg"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3376820041.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["sg"].replace("?", pd.NA, inplace=True)
combined_data["sg"].fillna(combined_data["sg"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\1807488879.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["sg"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\1807488879.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["al"].replace("?", pd.NA, inplace=True)
combined_data["al"].fillna(combined_data["al"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3671947293.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["al"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3671947293.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["su"].replace("?", pd.NA, inplace=True)
combined_data["su"].fillna(combined_data["su"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\2658199869.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["su"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\2658199869.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["rbc"].replace("?", pd.NA, inplace=True)
combined_data["rbc"].fillna(combined_data["rbc"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\1108234895.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["rbc"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\1108234895.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["pc"].replace("?", pd.NA, inplace=True)
combined_data["pc"].fillna(combined_data["pc"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3823952020.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["pc"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3823952020.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["pcc"].replace("?", pd.NA, inplace=True)
combined_data["pcc"].fillna(combined_data["pcc"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3836547879.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["pcc"].replace("?", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3836547879.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data["prediction"].replace("ckd\t", pd.NA, inplace=True)
combined_data["prediction"].fillna(combined_data["prediction"].mode()[0],inplace=True)
# Out:
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3619538853.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_data["prediction"].replace("ckd\t", pd.NA, inplace=True)
# C:\Users\sagar shresti\AppData\Local\Temp\ipykernel_8164\3619538853.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
combined_data.head(2)
# Out:
#   age  bg     sg al su     rbc      pc         pcc          ba  bgr  sc  sod  \
# 0  48  80  1.020  1  0  normal  normal  notpresent  notpresent  121  36  1.2
# 1   7  50  1.020  4  0  normal  normal  notpresent  notpresent   99  18  0.8
#
#    pot hemo   pcv wbcc  rbcc  htn   dm  cad appet    pe ane class prediction
# 0  135  3.5  15.4   44  7800  5.2  yes  yes    no  good  no    no        ckd
# 1  135  3.5  11.3   38  6000  5.2   no   no    no  good  no    no        ckd

# %%
combined_data.to_csv('cleaned_combined_ckd.csv', index=False)

# %%
print(combined_data['prediction'].value_counts())
# Out:
# prediction
# ckd       578
# notckd    319
# Name: count, dtype: int64
